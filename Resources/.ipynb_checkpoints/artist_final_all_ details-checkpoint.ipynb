# %%
import spotipy
import requests
import sys
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import random
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json
import time
import sys
from pprint import pprint
import os
import csv

# %%
client_id = "af2ec23866f84e8a8e3039b1d749938e"
client_secret = "e765f25f6d6443028cbfc2cd0259ed7c"
access_token="BQAgdUgqcAsOJt9nSZbYQ7y8_ZjdgHOTefl-7t925-2sSpSUYDEtUyBvCnUSh2PG16hkaeSKo0eIcTEJ9cRpyHe_dyuRALr6IdjmMIqq9TqJQjCCE87udMkrAgu780YwjQcuhRG6CyN3i8WxMV1ibdJnf-ASjhVxqBw2jraBKc_GCe8LdGCXl65lZoh32KjKCuK69E-TAe0G5YHW3rdRkEZXTily2xAPdOLx-hWKB9TmDWfC-DYHcu-dujzkkzHUAjje82kS"
# Setup the credentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Make the connection
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager,auth=access_token)

# %%
csv_path = "artistfinal_with_avgcomp.csv"
df=pd.read_csv(csv_path,encoding='UTF-8')
df.head()
# Out:
#     ID                         title  followers_count      genres  popularity  \
# 0      1      A Boogie Wit da Hoodie          1371562         pop          84
# 1      2          A Canorous Quintet              347         NaN           9
# 2      3         A Flock Of Seagulls           119714  dance rock          60
# 3      4                        a-ha           458004  dance rock          72
# 4      5  A Kiss To Build A Dream On               44         NaN           0
#
#    avgcompscore
# 0      0.410429
# 1     -0.535836
# 2      0.384815
# 3      0.167887
# 4     -0.979600

# %%
k=0

song_data={'album_name':[],'artist_name':[],'album_release_date':[]}

# %%
i="A Boogie Wit da Hoodie"
result=sp.search(i,limit=1, offset=0, type='album')
artist_name= result['albums']['items'][0]['artists'][0]['name']
#album_name=result['albums']['items'][0]['album']['name']
album_release_date= result['albums']['items'][0]['release_date']
album_name=result['albums']['items'][0]['name']
#pprint(result)
print(artist_name)
#print(album_name)
print(album_release_date)
print(album_name)
# Out:
# A Boogie Wit da Hoodie
# 2017-09-29
# The Bigger Artist

# %%
for i in df['title']:
    k=k+1
    result = sp.search(i,limit=1, offset=0, type='album', market="US")
    #pprint(result)
    sub=result['albums']['items']
    for follow in sub:
        artistname= sub[0]['artists'][0]['name']
        albumreleasedate= sub[0]['release_date']
        albumname=sub[0]['name']
        song_data['artist_name'].append(artistname)
        song_data['album_release_date'].append(albumreleasedate)
        song_data['album_name'].append(albumname)
        next
        print(k, i,albumname)
    next
# Out:
# 1 A Boogie Wit da Hoodie The Bigger Artist
# 2 A Canorous Quintet Alive from the World Beyond (Live)
# 3 A Flock Of Seagulls Playlist: The Very Best of A Flock of Seagulls
# 4 a-ha Hunting High And Low
# 5 A Kiss To Build A Dream On A Kiss to Build a Dream on
# 7 A La Carte Pop à la carte
# 8 A Perfect Circle Thirteenth Step
# 9 A Shrine You're a Stranger
# 10 A Static Lullaby Rattlesnake!
# 11 A Taste Of Honey A Taste Of Honey
# 13 A Tribe Called Quest We got it from Here... Thank You 4 Your service
# 14 F R A N C I S N.R.G (feat. F R A N C I S)
# 15 AFI DECEMBERUNDERGROUND
# 16 AK-Swift You Spin Me Round feat. A.K.Swift
# 17 Animal Collective Merriweather Post Pavilion
# 18 Apv Heat
# retrying ...1secs
# 19 A Boogie Wit da Hoodie The Bigger Artist
# 20 A1 A1
# 21 Aaliyah Age Ain't Nothing But A Number
# 22 Aaron Carter LØVË
# 23 Aaron Lines Living Out Loud
# 24 Aaron Neville The Very Best Of Aaron Neville
# 25 Aaron Tippin Greatest Hits And Then Some
# ...

# %%
cleaned_csv = zip(song_data['album_name'],song_data['album_release_date'],song_data['artist_name'])
print(cleaned_csv)

# %%
output_file = os.path.join("artist_final7.csv")
with open(output_file, "w", newline="", encoding="UTF-8") as datafile:
    writer = csv.writer(datafile)
    writer.writerow(["albumname","albumreleasedate","artistname"])
    writer.writerows(cleaned_csv)
