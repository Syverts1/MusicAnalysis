# %%
import spotipy
import requests
import sys
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import random
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json
import time
import sys
from pprint import pprint
import os
import csv

# %%
# ID and Password for accessing Spotify API
client_id = "af2ec23866f84e8a8e3039b1d749938e"
client_secret = "e765f25f6d6443028cbfc2cd0259ed7c"
access_token = "BQBAQRVLek8pFW0LzZsGd7mstvoVi_-MZl1ZNvBKyRyWIsGNLxEIWzc08l4lz7kD4SYvB_ZtCjg7LLi1YGTU_kK20jwmlDgUpL0W4o7ypq7OheLcgt8pRX_D1noJBbH8BjCBjvIpqVKPzSzmOnLrfZmdg6XoOTnjP_m3XPPC0Fwbjx-OzxB_3FooZTee3ctH2d5_NOQK2e8ieGyhw8SbSkRh4umCQw8aHYuRlVZRWjfh8eEpUwPqumSVPpZYGUA3ycxE2udv"
# Setup the credentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Make the connection
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager,auth=access_token)

# %%
csv_path = "artist.csv"
artist_df=pd.read_csv(csv_path,encoding="ANSI")
artist_df.head()
# Out:
#    id                       title  song_count                      slug
# 0   1                           A          21                         a
# 1   2          A Canorous Quintet          11        a-canorous-quintet
# 2   3         A Flock of Seagulls          30       a-flock-of-seagulls
# 3   4                        A Ha          16                    a-ha-2
# 4   5  A Jugend - Tsg Kirchhellen           1  a-jugend-tsg-kirchhellen

# %%
artist_df_title = artist_df[["title"]]

artist_df_title.head()
# Out:
#                         title
# 0                           A
# 1          A Canorous Quintet
# 2         A Flock of Seagulls
# 3                        A Ha
# 4  A Jugend - Tsg Kirchhellen

# %%
artist_csv=os.path.join("artist.csv")
#list to store data
index = []
id=[]
title=[]
song_count=[]      
followers_count=[]
genres=[]
popularity=[]
with open(artist_csv, newline="") as csvfile:
    csvreader= csv.reader(csvfile, delimiter=",")
    for row in csvreader:
        id.append(row[0])
        title.append(row[1])

        i="A"
        result=sp.search(i,limit=1, offset=0, type='artist', market="US")
        sub=result['artists']['items']
        for follow in sub:
            followers_count = sub[0]["followers"]["total"]
            genres = sub[0]["genres"]
            popularity=sub[0]["popularity"]
            print("Artist Name: " + str(i))
            print("total Count: " + str(followers_count))
            print("Category: "+ str(genres))
            print("Artist Popularity: " + str(popularity))
            
cleaned_csv = zip(id,title,song_count,followers_count,genres,popularity)
print(cleaned_csv)

output_file = os.path.join("artistfinal1.csv")
with open(output_file, "w", encoding="UTF-8") as datafile:
    writer = csv.writer(datafile)
    
    writer.writerow(["id", "title", "song_count",
                     "followers_count", "genres", "popularity"])
    writer.writerows(cleaned_csv)
# Out:
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# Category: ['pop', 'rap', 'trap music']
# Artist Popularity: 84
# Artist Name: A
# total Count: 1363053
# ...

# %%
artist_csv=os.path.join("artist.csv")
#list to store data
index = []
id=[]
title=[]
song_count=[]      
followers_count=[]
genres=[]
popularity=[]

# %%
for i in artist_df_title['title']:
    result = sp.search(i,limit=1, offset=0, type='artist', market="US")
    #pprint(result)
    sub=result['artists']['items']
    for follow in sub:
        followers_count = sub[0]["followers"]["total"]
        genres = sub[0]["genres"]
        popularity=sub[0]["popularity"]
        pprint("Artist Name: "+ str(i))
        pprint("total Count: " + str(followers_count))
        pprint("Category: "+ str(genres))
        pprint("Artist Popularity: " + str(popularity))
        next
    next
# Out:
# 'Artist Name: A'
# 'total Count: 1363084'
# "Category: ['pop', 'rap', 'trap music']"
# 'Artist Popularity: 84'
# 'Artist Name: A Canorous Quintet'
# 'total Count: 347'
# 'Category: []'
# 'Artist Popularity: 9'
# 'Artist Name: A Flock of Seagulls'
# 'total Count: 119232'
# ("Category: ['dance rock', 'new romantic', 'new wave', 'new wave pop', "
#  "'synthpop']")
# 'Artist Popularity: 60'
# 'Artist Name: A Ha'
# 'total Count: 456321'
# ("Category: ['dance rock', 'new romantic', 'new wave', 'new wave pop', "
#  "'permanent wave', 'soft rock', 'synthpop']")
# 'Artist Popularity: 72'
# 'Artist Name: A Kiss To Build A Dream On'
# 'total Count: 44'
# 'Category: []'
# 'Artist Popularity: 0'
# 'Artist Name: A Klana Indiana'
# 'total Count: 174'
# 'Category: []'
# 'Artist Popularity: 18'
# 'Artist Name: A La Carte'
# 'total Count: 993'
# "Category: ['italian disco']"
# 'Artist Popularity: 26'
# 'Artist Name: A Perfect Circle'
# 'total Count: 557102'
# ...

# %%
cleaned_csv = zip(id,title,song_count,followers_count,genres,popularity)
print(cleaned_csv)

output_file = os.path.join("artistfinal1.csv")
with open(output_file, "w", newline="", encoding="UTF-8") as datafile:
    writer = csv.writer(datafile)
    
    writer.writerow(["id", "title", "song_count",
                     "followers_count", "genres", "popularity"])
    writer.writerows(cleaned_csv)

# %%
cleaned_csv = zip(id,title,song_count,followers_count,genres,popularity)
print(cleaned_csv)

# %%
# Lists to store data
index = []
id=[]
title=[]
song_count=[]      
followers_count=[]
genres=[]
popularity=[]

# %%
# Create Dataframe and fill lists for id, title and song_count
csv_path = "artist.csv"
artist_df=pd.read_csv(csv_path,encoding="ANSI")
id=artist_df['id'].unique()
title= artist_df['title'].unique()
song_count=artist_df['song_count']
len(title),len(id), len(song_count)
# Out:
# (9820, 9820, 9820)

# %%
for i in title:
    result = sp.search(i,limit=1, offset=0, type='artist', market="US")
    #pprint(result)
    sub=result['artists']['items']
    for follow in sub:
        followerscount = sub[0]["followers"]["total"]
        #genres = sub[0]["genres"]
        popular=sub[0]["popularity"]
        followers_count.append(followerscount)
        #genres.append(genres)
        popularity.append(popular)
        pprint(i)
        next
    next
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-e51ccc934068> in <module>()
#       1 for i in title:
# ----> 2     result = sp.search(i,limit=1, offset=0, type='artist', market="US")
#       3     #pprint(result)
#       4     sub=result['artists']['items']
#       5     for follow in sub:
#
# ~\Anaconda\lib\site-packages\spotipy\client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# ...

# %%
#cleaned_csv = zip(id,title,song_count,followers_count,genres,popularity)

cleaned_csv = zip(id,title,song_count,followers_count,popularity)  # dropped genres
print(cleaned_csv)

# %%
 #Send Data to output file
output_file = os.path.join("artistfinal2.csv")
with open(output_file, "w", newline="", encoding="UTF-8") as datafile:
    writer = csv.writer(datafile)
    
    #writer.writerow(["id", "title", "song_count","followers_count", "genres", "popularity"])
    
    writer.writerow(["id", "title", "song_count","followers_count", "popularity"]) # dropped genres
    
    writer.writerows(cleaned_csv)
