# %%
print ("Observation Trends and Conclusions - To Do")
# Out:
# Observation Trends and Conclusions - To Do

# %%
import sys
import numpy as np
import random
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json
import time
import sys
from pprint import pprint
import os
import csv
import seaborn as sns

# %%
#Songs and Artists with Spotify Consolidatd Data - "artistfinal_with_avgcomp.csv"

# %%
csv_path = "artistfinal_with_avgcomp.csv"
songs_df=pd.read_csv(csv_path,encoding='ANSI')
songs_df.head()
#len(songs_df)
# Out:
#     ID                         title  followers_count  \
# 0      1      A Boogie Wit da Hoodie          1371562
# 1      2          A Canorous Quintet              347
# 2      3         A Flock Of Seagulls           119714
# 3      4                        a-ha           458004
# 4      5  A Kiss To Build A Dream On               44
#
#                                               genres  popularity  avgcompscore
# 0                       ['pop', 'rap', 'trap music']          84      0.410429
# 1                                                 []           9     -0.535836
# 2  ['dance rock', 'new romantic', 'new wave', 'ne...          60      0.384815
# 3  ['dance rock', 'new romantic', 'new wave', 'ne...          72      0.167887
# 4                                                 []           0     -0.979600

# %%
#Popularity vs. Sentiment Plot
plt.figure(figsize=(10,7))
plt.scatter(songs_df["popularity"],songs_df["avgcompscore"])
#plt.scatter(pd.to_numeric(songs_df["popularity"]), pd.to_numeric(songs_df["avgcompscore"]))
sns.set()
plt.grid(True)
plt.title(f"Song Sentiment vs. Popularity (Spotify)", fontsize=20)
plt.axhline(y=0, color = 'black') #adds a horizontal line at zero
plt.ylabel("Average Coumpound Score", fontsize=14)
plt.xlabel("Popularity (Ranking)", fontsize=14)
plt.ylim(-1, 1)
plt.xlim(0, 100)
plt.show()

# %%
df = songs_df.groupby("popularity")["avgcompscore"].mean().reset_index()
df.head()
#len(df)
# Out:
#    popularity  avgcompscore
# 0           0      0.072462
# 1           1      0.064096
# 2           2     -0.037841
# 3           3      0.199258
# 4           4      0.133215

# %%
pop_gt0 = df["popularity"] > 0
df = df[pop_gt0]
df.head()
# Out:
#    popularity  avgcompscore
# 1           1      0.064096
# 2           2     -0.037841
# 3           3      0.199258
# 4           4      0.133215
# 5           5      0.148441

# %%
#Popularity vs. Sentiment Plot
x=df["popularity"]
y=df["avgcompscore"]

plt.figure(figsize=(10,7))
plt.scatter(x,y)
#plt.scatter(pd.to_numeric(songs_df["popularity"]), pd.to_numeric(songs_df["avgcompscore"]))
sns.set()
plt.grid(True)
plt.title(f"Song Sentiment vs. Popularity (Spotify)", fontsize=20)
plt.axhline(y=0, color = 'black') #adds a horizontal line at zero
plt.ylabel("Sentiment Average Compound Score", fontsize=14)
plt.xlabel("Popularity (Ranking)", fontsize=14)
#plt.ylim(-1, 1)
#plt.xlim(0, 100)
plt.show()

# %%
# Billboard Charts Consolidated Data - "billboard_sentanalys.csv"

# %%
csv_path = "billboard_sentanalys.csv"
songs_df2=pd.read_csv(csv_path,encoding='ANSI')
#songs_df2.head()

# %%
df = songs_df2.groupby("Rank")["comp_score"].mean().reset_index()
df.head()
#len(df)
# Out:
#    Rank  comp_score
# 0     1    0.399602
# 1     2    0.503980
# 2     3    0.586488
# 3     4    0.523957
# 4     5    0.567443

# %%
x=df["Rank"]
y=df["comp_score"]

plt.figure(figsize=(10,7))
sns.set()
plt.grid(True)
plt.scatter(x,y)
plt.title("Song Sentiment vs. Popularity (Billboard Charts)", fontsize=20)
plt.xlabel("Popularity (Ranking) ",fontsize=14)
#plt.axhline(y=0, color = 'black') #adds a horizontal line at zero
plt.ylabel("Sentiment Average Compound Score",fontsize=14)
#plt.xlim(1,100)
#plt.ylim(-1,1)
plt.show()

# %%
df = songs_df2.groupby("Year")["comp_score"].mean().reset_index()
df.head()
# Out:
#    Year  comp_score
# 0  1965    0.466193
# 1  1966    0.472391
# 2  1967    0.560155
# 3  1968    0.497356
# 4  1969    0.582143

# %%
x=df["Year"]
y=df["comp_score"]

plt.figure(figsize=(10,7))
sns.set()
plt.grid(True)
plt.scatter(x,y)
plt.title("Song Sentiment Over Time (Release Year - Billboard Charts)", fontsize=20)
plt.xlabel("Release Year", fontsize=14)
plt.ylabel("Sentiment Average Compound Score",fontsize=14)
#plt.xlim(1965,2017)
#plt.ylim(-.5,1)
plt.show()

# %%
df = songs_df2.groupby("Artist")["Rank"].count().reset_index()
#df = df.sort_values(by=["Rank"], axis=0, ascending=False)
df.head(50)
# Out:
#                                                Artist  Rank
# 0                              100 proof aged in soul     1
# 1                                       10000 maniacs     1
# 2                                                10cc     2
# 3                                                 112     3
# 4                            112 featuring foxy brown     1
# 5                              112 featuring lil zane     1
# 6            112 featuring the notorious big and mase     1
# 7                               1910 fruitgum company     3
# 8                                            2 chainz     1
# 9                            2 chainz featuring drake     1
# 10             2 pistols featuring tpain and tay dizm     1
# 11                      20 fingers featuring gillette     1
# 12                                          21 savage     1
# 13                                               2pac     4
# 14                       2pac featuring eric williams     1
# 15         2pac featuring kci, jojo, featuring dr dre     1
# 16                                       3 doors down     8
# 17                                         38 special     2
# 18                                                3lw     1
# 19                                               3oh3     1
# 20                                3oh3 featuring keha     1
# 21                                                 3t     1
# 22                                      4 non blondes     1
# 23                                            4:00 PM     1
# 24                                5 seconds of summer     2
# 25                                            50 cent     5
# 26  50 cent featuring justin timberlake and timbaland     1
# 27                        50 cent featuring mobb deep     1
# 28                        50 cent featuring nate dogg     1
# 29                           50 cent featuring olivia     1
# 30                                            69 boyz     2
# 31                                                702     2
# 32                                            8th day     1
# 33                                           95 south     1
# 34                                         98 degrees     6
# 35     a boogie wit da hoodieÂ featuringÂ kodak black     1
# 36                                a flock of seagulls     1
# 37           a great big world and christina aguilera     1
# 38                                   a taste of honey     2
# 39                                            aaliyah    11
# 40                                         aaron hall     1
# 41                                      aaron neville     2
# 42                                               abba     6
# 43                                                abc     2
# 44                                                ace     1
# 45                                        ace frehley     1
# 46            ace hood featuring future and rick ross     1
# 47                                        ace of base     6
# 48                                           adam ant     1
# 49                      adam clayton and larry mullen     1

# %%
rank_gt11 = df["Rank"] > 11
df = df[rank_gt11]
df = df.sort_values(by=["Rank"], axis=0, ascending=False).reset_index().reset_index()
df.head()
# Out:
#    level_0  index           Artist  Rank
# 0        0   1428          madonna    35
# 1        1    713       elton john    26
# 2        2   1441     mariah carey    25
# 3        3   2105    stevie wonder    22
# 4        4   1527  michael jackson    22

# %%
x=df["Artist"]
y=df["Rank"]

plt.figure(figsize=(10,7))
sns.set()
plt.grid(True)

plt.bar(x,y)
plt.title("Artist Longevity in Boillboard Charts ", fontsize =20)
plt.xlabel("Popularity (Ranking) ", fontsize=14)
plt.ylabel("Artist", fontsize=14)
plt.xticks(rotation=90)

#plt.ylim(1,100)
#plt.ylim(-1,1)
plt.show()
